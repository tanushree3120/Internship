# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5, 5, 0.25)

# %%
x
# Out:
# array([-5.  , -4.75, -4.5 , -4.25, -4.  , -3.75, -3.5 , -3.25, -3.  ,
#        -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  , -0.75,
#        -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,
#         1.75,  2.  ,  2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,
#         4.  ,  4.25,  4.5 ,  4.75])

# %%
y = 1.2 * x + 10.34   # linear eq

# %%
y
# Out:
# array([ 4.34,  4.64,  4.94,  5.24,  5.54,  5.84,  6.14,  6.44,  6.74,
#         7.04,  7.34,  7.64,  7.94,  8.24,  8.54,  8.84,  9.14,  9.44,
#         9.74, 10.04, 10.34, 10.64, 10.94, 11.24, 11.54, 11.84, 12.14,
#        12.44, 12.74, 13.04, 13.34, 13.64, 13.94, 14.24, 14.54, 14.84,
#        15.14, 15.44, 15.74, 16.04])

# %%
plt.plot(x, y);
