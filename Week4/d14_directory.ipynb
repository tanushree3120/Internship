# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Series

# %%
s = pd.Series([23, 45, 67, 12, 120, 56])

# %%
s
# Out:
# 0     23
# 1     45
# 2     67
# 3     12
# 4    120
# 5     56
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s = pd.Series([23, 45, 67, 12, 120, 56.0])
s
# Out:
# 0     23.0
# 1     45.0
# 2     67.0
# 3     12.0
# 4    120.0
# 5     56.0
# dtype: float64

# %%
s[2] = 100

# %%
s
# Out:
# 0     23.0
# 1     45.0
# 2    100.0
# 3     12.0
# 4    120.0
# 5     56.0
# dtype: float64

# %%
del s[2]

# %%
s
# Out:
# 0     23.0
# 1     45.0
# 3     12.0
# 4    120.0
# 5     56.0
# dtype: float64

# %%
s = pd.Series([23, 45, 67, 12, 120, 56.0], index = range(100,106))
s
# Out:
# 100     23.0
# 101     45.0
# 102     67.0
# 103     12.0
# 104    120.0
# 105     56.0
# dtype: float64

# %%
s[101]
# Out:
# 45.0

# %%
roll = pd.Series([1, 2, 3, 4, 5])
name = pd.Series(['Ajay', 'Sia', 'Natasha', 'Ravindra', 'Anuj'])
marks = pd.Series([67, 78, 65, 88])

# %%
name
# Out:
# 0        Ajay
# 1         Sia
# 2     Natasha
# 3    Ravindra
# 4        Anuj
# dtype: object

# %%
df = pd.DataFrame({
    'roll': roll,
    'name': name,
    'marks':marks

})
df
# Out:
#    roll      name  marks
# 0     1      Ajay   67.0
# 1     2       Sia   78.0
# 2     3   Natasha   65.0
# 3     4  Ravindra   88.0
# 4     5      Anuj    NaN

# %%
df.shape
# Out:
# (5, 3)

# %%
df.size
# Out:
# 15

# %%
df.columns
# Out:
# Index(['roll', 'name', 'marks'], dtype='object')

# %% [markdown]
# ### current working directory

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Admin'

# %%
"""
location => https://mitu.co.in/dataset
download all the files starting from student*.csv
eg... student1.csv,students.csv,.....

put them into same directpry as your jupiter notebook files

"""""
# Out:
# '\nlocation => https://mitu.co.in/dataset\ndownload all the files starting from student*.csv\neg... student1.csv,students.csv,.....\n\nput them into same directpry as your jupiter notebook files\n\n'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("student5.csv")
df
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
df = pd.read_csv("student2.csv")
df
# Out:
#    roll     name class  marks   age
# 0     1     anil    TE  56.77  22.0
# 1     2     amit    TE  59.77  21.0
# 2     3   aniket    BE  76.88  19.0
# 3     4  ajinkya    TE  69.66   NaN
# 4     5     asha   NaN  63.28  20.0
# 5     6   ayesha    BE  49.55  20.0
# 6     7     amar    BE    NaN  19.0
# 7     8    amita    BE    NaN  23.0
# 8     9     amol    TE  56.75  20.0
# 9    10    anmol    BE  78.66  21.0

# %%
headers = ["A", "B", "C", "D","E"]
df1 = pd.read_csv("student2.csv", names =headers)

# %%
df1
# Out:
#        A        B      C      D    E
# 0   roll     name  class  marks  age
# 1      1     anil     TE  56.77   22
# 2      2     amit     TE  59.77   21
# 3      3   aniket     BE  76.88   19
# 4      4  ajinkya     TE  69.66  NaN
# 5      5     asha    NaN  63.28   20
# 6      6   ayesha     BE  49.55   20
# 7      7     amar     BE    NaN   19
# 8      8    amita     BE    NaN   23
# 9      9     amol     TE  56.75   20
# 10    10    anmol     BE  78.66   21

# %%
df = pd.read_csv("student3.csv")
df
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df = pd.read_csv("student3.csv")
df
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df1 = pd.read_csv("student3.tsv",sep = '\t')
df1
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df = pd.read_csv("student3.csv")
df
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df.shape
# Out:
# (16, 5)

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks ', 'age'], dtype='object')

# %%
df.size
# Out:
# 80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    16 non-null     int64
#  1   name    16 non-null     object
#  2   class   15 non-null     object
#  3   marks   14 non-null     float64
#  4   age     14 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 772.0+ bytes

# %%
df.T
# Out:
#            0      1       2        3      4       5      6      7      8   \
# roll        1      2       3        4      5       6      7      8      9
# name     anil   amit  aniket  ajinkya   asha  ayesha   amar  Amita   amol
# class      TE     TE      BE       TE     TE      BE     BE     be     TE
# marks   56.77  59.77   76.88    69.66  63.28     NaN  65.34  68.33  56.75
# age      22.0   21.0    19.0     20.0    NaN    20.0   19.0   23.0   20.0
#
#            9      10      11     12       13      14       15
# roll        9     10      11     12       13      14       15
# name     amol  anmol  surbhi  Sujay  subhash  sachin  shalini
# class      TE     BE      TE     TE       be     NaN       TE
# marks   56.75  78.66     NaN  74.12    88.45   59.33    63.45
# age      20.0    NaN    23.0   22.0     21.0    21.0     20.0

# %%
df.dtypes
# Out:
# roll        int64
# name       object
# class      object
# marks     float64
# age       float64
# dtype: object

# %%
df.head(3)
# Out:
#    roll    name class  marks    age
# 0     1    anil    TE   56.77  22.0
# 1     2    amit    TE   59.77  21.0
# 2     3  aniket    BE   76.88  19.0

# %%
df.tail()
# Out:
#     roll     name class  marks    age
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df.describe()
# Out:
#             roll     marks         age
# count  16.000000  14.000000  14.000000
# mean    8.062500  66.967143  20.785714
# std     4.327721   9.640749   1.311404
# min     1.000000  56.750000  19.000000
# 25%     4.750000  59.440000  20.000000
# 50%     8.500000  64.395000  20.500000
# 75%    11.250000  73.005000  21.750000
# max    15.000000  88.450000  23.000000

# %%
df
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df.iloc[2:5, 0:3]
# Out:
#    roll     name class
# 2     3   aniket    BE
# 3     4  ajinkya    TE
# 4     5     asha    TE

# %%
x = df.iloc[2:5, 0:3]
x
# Out:
#    roll     name class
# 2     3   aniket    BE
# 3     4  ajinkya    TE
# 4     5     asha    TE

# %%
x = df.iloc[2:5, 0:3]
x
# Out:
#    roll     name class
# 2     3   aniket    BE
# 3     4  ajinkya    TE
# 4     5     asha    TE

# %%
x = df.iloc[5:9, 0:3]
x
# Out:
#    roll    name class
# 5     6  ayesha    BE
# 6     7    amar    BE
# 7     8   Amita    be
# 8     9    amol    TE

# %%
df.iloc[[5, 6, 8], 0:3]
# Out:
#    roll    name class
# 5     6  ayesha    BE
# 6     7    amar    BE
# 8     9    amol    TE

# %%
df.loc[: ,'name']
# Out:
# 0        anil
# 1        amit
# 2      aniket
# 3     ajinkya
# 4        asha
# 5      ayesha
# 6        amar
# 7       Amita
# 8        amol
# 9        amol
# 10      anmol
# 11     surbhi
# 12      Sujay
# 13    subhash
# 14     sachin
# 15    shalini
# Name: name, dtype: object

# %%
df['name']
# Out:
# 0        anil
# 1        amit
# 2      aniket
# 3     ajinkya
# 4        asha
# 5      ayesha
# 6        amar
# 7       Amita
# 8        amol
# 9        amol
# 10      anmol
# 11     surbhi
# 12      Sujay
# 13    subhash
# 14     sachin
# 15    shalini
# Name: name, dtype: object

# %%
df.drop(9)
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df.drop('roll', axis = 1)
# Out:
#        name class  marks    age
# 0      anil    TE   56.77  22.0
# 1      amit    TE   59.77  21.0
# 2    aniket    BE   76.88  19.0
# 3   ajinkya    TE   69.66  20.0
# 4      asha    TE   63.28   NaN
# 5    ayesha    BE     NaN  20.0
# 6      amar    BE   65.34  19.0
# 7     Amita    be   68.33  23.0
# 8      amol    TE   56.75  20.0
# 9      amol    TE   56.75  20.0
# 10    anmol    BE   78.66   NaN
# 11   surbhi    TE     NaN  23.0
# 12    Sujay    TE   74.12  22.0
# 13  subhash    be   88.45  21.0
# 14   sachin   NaN   59.33  21.0
# 15  shalini    TE   63.45  20.0

# %%
# renaming

# %%
col = {'roll': 'id'}

# %%
df.rename(columns= col)
# Out:
#     id     name class  marks    age
# 0    1     anil    TE   56.77  22.0
# 1    2     amit    TE   59.77  21.0
# 2    3   aniket    BE   76.88  19.0
# 3    4  ajinkya    TE   69.66  20.0
# 4    5     asha    TE   63.28   NaN
# 5    6   ayesha    BE     NaN  20.0
# 6    7     amar    BE   65.34  19.0
# 7    8    Amita    be   68.33  23.0
# 8    9     amol    TE   56.75  20.0
# 9    9     amol    TE   56.75  20.0
# 10  10    anmol    BE   78.66   NaN
# 11  11   surbhi    TE     NaN  23.0
# 12  12    Sujay    TE   74.12  22.0
# 13  13  subhash    be   88.45  21.0
# 14  14   sachin   NaN   59.33  21.0
# 15  15  shalini    TE   63.45  20.0

# %%
ind = {1: 'one', 3: 'three'}

# %%
df.rename(index = ind)
# Out:
#        roll     name class  marks    age
# 0         1     anil    TE   56.77  22.0
# one       2     amit    TE   59.77  21.0
# 2         3   aniket    BE   76.88  19.0
# three     4  ajinkya    TE   69.66  20.0
# 4         5     asha    TE   63.28   NaN
# 5         6   ayesha    BE     NaN  20.0
# 6         7     amar    BE   65.34  19.0
# 7         8    Amita    be   68.33  23.0
# 8         9     amol    TE   56.75  20.0
# 9         9     amol    TE   56.75  20.0
# 10       10    anmol    BE   78.66   NaN
# 11       11   surbhi    TE     NaN  23.0
# 12       12    Sujay    TE   74.12  22.0
# 13       13  subhash    be   88.45  21.0
# 14       14   sachin   NaN   59.33  21.0
# 15       15  shalini    TE   63.45  20.0

# %%
df['roll'] = df['roll'] + 100

# %%
df
# Out:
#     roll     name class  marks    age
# 0    101     anil    TE   56.77  22.0
# 1    102     amit    TE   59.77  21.0
# 2    103   aniket    BE   76.88  19.0
# 3    104  ajinkya    TE   69.66  20.0
# 4    105     asha    TE   63.28   NaN
# 5    106   ayesha    BE     NaN  20.0
# 6    107     amar    BE   65.34  19.0
# 7    108    Amita    be   68.33  23.0
# 8    109     amol    TE   56.75  20.0
# 9    109     amol    TE   56.75  20.0
# 10   110    anmol    BE   78.66   NaN
# 11   111   surbhi    TE     NaN  23.0
# 12   112    Sujay    TE   74.12  22.0
# 13   113  subhash    be   88.45  21.0
# 14   114   sachin   NaN   59.33  21.0
# 15   115  shalini    TE   63.45  20.0

# %%
#
Q1
Create series using a list of 5 fruit names.Assign custom index labels to each elment.

# %%
import pandas as pd

fruits = ['Apple', 'Banana', 'Grapes', 'Mango', 'Chikoo']
labels = ['A', 'B', 'C', 'D','E']
fruit_series = pd.Series(fruits, index=labels)

# %%
print(fruit_series)
# Out:
# A     Apple
# B    Banana
# C    Grapes
# D     Mango
# E    Chikoo
# dtype: object

# %%
#
Q2
Create a DataFrame from the following dictionary.

{
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['Pune', 'Mumbai', 'Nagpur']
}

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['Pune', 'Mumbai', 'Nagpur']
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age    City
# 0    Alice   25    Pune
# 1      Bob   30  Mumbai
# 2  Charlie   35  Nagpur

# %%
# 
Q3
Create a DataFrame using Numpy to generate a 3x3 matrix of random intergers between 1 and 100. 
Assign column names as 'A','B','C'.

# %%
df = pd.DataFrame(np.random.randint(1, 101, (3, 3)), columns=['A', 'B', 'C'])
print(df)
# Out:
#     A   B   C
# 0  66  54  43
# 1  70  76  63
# 2  70  62  72

# %%
#
Q4
Using the DataFrame from Question 2, display:- First 2 rows - Last row - shape of the DataFrame

# %%
print(df.head(2))
# Out:
#     A   B   C
# 0  66  54  43
# 1  70  76  63

# %%
print(df.tail(1))
# Out:
#     A   B   C
# 2  70  62  72

# %%
print(df.shape)
# Out:
# (3, 3)
